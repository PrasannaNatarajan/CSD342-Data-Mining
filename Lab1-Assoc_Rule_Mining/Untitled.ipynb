# %%
from wordcloud import WordCloud

# %%
import pandas

# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C,S = np.cos(X), np.sin(X)

plt.plot(X,C)
plt.plot(X,S)

plt.show()

# %%
data = pandas.read_csv("C:\\Users\\prasanna\\Documents\\Studies\\Semester 6\\Data mining\\labs\\lab1_test\\output.csv")

# %%
data
# Out:
#                                         Item Sets  Threshold
# 0                  {?citrus fruit tropical fruit}        350
# 1                      {?citrus fruit whole milk}        357
# 2                       {?citrus fruit pip fruit}        344
# 3                {?citrus fruit other vegetables}        323
# 4                      {?citrus fruit rolls/buns}        321
# 5                      {?citrus fruit pot plants}        298
# 6                            {?citrus fruit beef}        315
# 7                     {?citrus fruit frankfurter}        330
# 8                         {?citrus fruit chicken}        316
# 9                     {tropical fruit whole milk}        340
# 10                     {tropical fruit pip fruit}        309
# 11              {tropical fruit other vegetables}        338
# 12                    {tropical fruit rolls/buns}        319
# 13                    {tropical fruit pot plants}        292
# ...

# %%
data_sorted = data.sort_values(by='Threshold')

# %%
data_sorted.head()
# Out:
#                                         Item Sets  Threshold
# 74          {tropical fruit pip fruit pot plants}        100
# 69   {tropical fruit whole milk other vegetables}        100
# 93          {whole milk other vegetables chicken}        100
# 64             {?citrus fruit rolls/buns chicken}        100
# 106            {pip fruit rolls/buns frankfurter}        100

# %%
data_sorted.boxplot(return_type='axes')
plt.show()

# %%
data_sorted[-10:-1].plot(kind ='bar')
plt.show()

# %%
data_sorted[1:10].plot(kind='bar', legend = "True")
plt.show()

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

words = ' '.join(data_sorted['Item Sets'][1:10])

print words
wordcloud = WordCloud(
                      stopwords=STOPWORDS,
                      background_color='black',
                     ).generate(words)

plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('./my_first_wordcloud_1.png', dpi=300)
plt.show()
# Out:
# {rolls_buns_pot_plants_chicken} {rolls_buns_pot_plants_chicken} {rolls_buns_pot_plants_chicken} {rolls_buns_pot_plants_chicken} {rolls_buns_pot_plants_chicken} {rolls_buns_pot_plants_chicken} {rolls_buns_pot_plants_chicken} {rolls_buns_pot_plants_chicken} {rolls_buns_pot_plants_chicken}

# %%
for x in data_sorted['Item Sets']:
    data_sorted['Item Sets'] = x.replace(" ","_")
    data_sorted['Item Sets'] = x.replace("/","_")
    
print data_sorted['Item Sets']
# Out:
# 101    {rolls_buns_pot_plants_chicken}
# 99     {rolls_buns_pot_plants_chicken}
# 85     {rolls_buns_pot_plants_chicken}
# 78     {rolls_buns_pot_plants_chicken}
# 77     {rolls_buns_pot_plants_chicken}
# 62     {rolls_buns_pot_plants_chicken}
# 98     {rolls_buns_pot_plants_chicken}
# 52     {rolls_buns_pot_plants_chicken}
# 51     {rolls_buns_pot_plants_chicken}
# 94     {rolls_buns_pot_plants_chicken}
# 87     {rolls_buns_pot_plants_chicken}
# 49     {rolls_buns_pot_plants_chicken}
# 57     {rolls_buns_pot_plants_chicken}
# 58     {rolls_buns_pot_plants_chicken}
# 47     {rolls_buns_pot_plants_chicken}
# 66     {rolls_buns_pot_plants_chicken}
# 70     {rolls_buns_pot_plants_chicken}
# 64     {rolls_buns_pot_plants_chicken}
# 65     {rolls_buns_pot_plants_chicken}
# 61     {rolls_buns_pot_plants_chicken}
# 60     {rolls_buns_pot_plants_chicken}
# 59     {rolls_buns_pot_plants_chicken}
# 88     {rolls_buns_pot_plants_chicken}
# 67     {rolls_buns_pot_plants_chicken}
# ...
